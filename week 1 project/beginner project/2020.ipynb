# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("IT Salary Survey EU  2020.csv")

# %%
df.head()
# Out:
#              Timestamp   Age Gender    City            Position  \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#    Total years of experience  Years of experience in Germany Seniority level  \
# 0                        5.0                             3.0          Senior
# 1                        7.0                             4.0          Senior
# 2                       12.0                             6.0            Lead
# 3                        4.0                             1.0          Junior
# 4                       17.0                             6.0          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# 1                                        Ruby
# 2                     Javascript / Typescript
# 3                                  Javascript
# 4                                     C# .NET
#
#   Other technologies/programming languages you use often  ...  \
# 0                    Kotlin, Javascript / Typescript      ...
# 1                                                NaN      ...
# 2                    Javascript / Typescript, Docker      ...
# 3                                                NaN      ...
# 4                             .NET, SQL, AWS, Docker      ...
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days           Employment status   Сontract duration  \
# 0                      30          Full-time employee  Unlimited contract
# 1                      28          Full-time employee  Unlimited contract
# 2                      30  Self-employed (freelancer)  Temporary contract
# 3                      24          Full-time employee  Unlimited contract
# 4                      29          Full-time employee  Unlimited contract
#
#   Main language at work Company size Company type  \
# 0               English       51-100      Product
# 1               English     101-1000      Product
# 2               English     101-1000      Product
# 3               English       51-100      Startup
# 4               English     101-1000      Product
#
#   Have you lost your job due to the coronavirus outbreak?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1247  18/01/2021 15:05:50  31.0   Male       Berlin
# 1248  18/01/2021 17:46:02  33.0   Male       Berlin
# 1249  18/01/2021 23:20:35  39.0   Male       Munich
# 1250  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1251  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                     Position  Total years of experience  \
# 1247                       Backend Developer                        9.0
# 1248  Researcher/ Consumer Insights Analyst                        10.0
# 1249                   IT Operations Manager                       15.0
# 1250                      Frontend Developer                        7.0
# 1251                                  DevOps                        2.0
#
#       Years of experience in Germany Seniority level  \
# 1247                             5.0          Senior
# 1248                             1.5          Senior
# 1249                             2.0            Lead
# 1250                             7.0          Middle
# 1251                             2.0          Middle
#
#      Your main technology / programming language  \
# 1247                                        Java
# 1248                           consumer analysis
# 1249                                         PHP
# 1250                                  JavaScript
# 1251                                        yaml
#
#      Other technologies/programming languages you use often  ...  \
# 1247  Python, Javascript / Typescript, Java / Scala,...      ...
# 1248                                                NaN      ...
# 1249  Python, C/C++, Javascript / Typescript, Java /...      ...
# 1250  Javascript / Typescript, Docker, HTML, CSS; Ad...      ...
# 1251  Python, AWS, Kubernetes, Docker, terraform, an...      ...
#
#       Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 1247                                              72000
# 1248                                               2500
# 1249                                                NaN
# 1250                                              36400
# 1251                                                  0
#
#      Number of vacation days   Employment status   Сontract duration  \
# 1247                      26  Full-time employee  Unlimited contract
# 1248              unlimited   Full-time employee  Unlimited contract
# 1249                      28  Full-time employee  Unlimited contract
# 1250                      27  Full-time employee  Unlimited contract
# 1251                      30  Full-time employee  Unlimited contract
#
#      Main language at work Company size Company type  \
# 1247               English       51-100      Product
# 1248               English        1000+      Product
# 1249               English     101-1000    eCommerce
# 1250                German     101-1000      Product
# 1251               English       51-100      Startup
#
#      Have you lost your job due to the coronavirus outbreak?  \
# 1247                                                Yes
# 1248                                                 No
# 1249                                                 No
# 1250                                                 No
# 1251                                                 No
#
#      Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 1247                                                NaN
# 1248                                                NaN
# 1249                                                NaN
# 1250                                                NaN
# 1251                                               30.0
#
#      Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 1247                                                NaN
# 1248                                                  0
# 1249                                                NaN
# 1250                                                  0
# 1251                                                600
#
# [5 rows x 23 columns]

# %%
df[['Position', 'Seniority level','Annual bonus+stocks one year ago. Only answer if staying in same country']].head(10)
# Out:
#              Position Seniority level  \
# 0   Software Engineer          Senior
# 1   Backend Developer          Senior
# 2   Software Engineer            Lead
# 3  Frontend Developer          Junior
# 4   Backend Developer          Senior
# 5              DevOps          Senior
# 6  Frontend Developer          Middle
# 7  Frontend Developer          Senior
# 8   Backend Developer          Senior
# 9   Software Engineer            Lead
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
# 5                                               5000
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
df['Total years of experience'].describe()
# Out:
# count    1235.000000
# mean        9.051498
# std        11.885911
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        12.000000
# max       383.000000
# Name: Total years of experience, dtype: float64

# %%
#converting the columns to a numeric type
df['Total years of experience']=pd.to_numeric(df['Total years of experience'])
df['Years of experience in Germany']=pd.to_numeric(df['Years of experience in Germany'])


# I encountered Value Errors in string instances with a comma i.e "1,5" and changed less than a year entries to 0
df['Total years of experience'].describe()
# Out:
# count    1235.000000
# mean        9.051498
# std        11.885911
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        12.000000
# max       383.000000
# Name: Total years of experience, dtype: float64

# %%
df['Years of experience in Germany'].isna().values.any()
# Out:
# True

# %%
df['Years of experience in Germany'].fillna(0, inplace=True)

# %%
df['Years of experience in Germany'].isna().values.any()
# Out:
# False

# %%
df['Years of experience in Germany'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
levels={level for level in df['Seniority level'] }
levels
# Out:
# {'C-Level',
#  'C-level executive manager',
#  'CTO',
#  'Director',
#  'Entry level',
#  'Head',
#  'Intern',
#  'Junior',
#  'Key',
#  'Lead',
#  'Manager',
#  'Middle',
#  'No level',
#  'No level ',
#  'Principal',
#  'Self employed',
#  'Senior',
#  'Student',
#  'VP',
#  'Work Center Manager',
#  'Working Student',
#  'intern',
#  nan,
#  'no idea, there are no ranges in the firm ',
#  'student'}

# %%
df.Age.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

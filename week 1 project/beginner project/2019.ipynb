# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("IT Salary Survey EU 2019.csv")

# %%
df.head()
# Out:
#            Zeitstempel   Age Gender    City Seniority level  \
# 0  02.12.2019 11:18:26  33.0   Male  Berlin          Senior
# 1  02.12.2019 11:18:35  29.0   Male  Berlin          Middle
# 2  02.12.2019 11:18:56   NaN   Male  Berlin          Middle
# 3  02.12.2019 11:19:08  30.0   Male  Berlin          Senior
# 4  02.12.2019 11:19:37  32.0   Male  Berlin          Senior
#
#   Position (without seniority)  Years of experience  \
# 0          Fullstack Developer                   13
# 1            Backend Developer                    3
# 2             Mobile Developer                    4
# 3            Backend Developer                    6
# 4           Embedded Developer                   10
#
#   Your main technology / programming language  \
# 0                                         PHP
# 1                                      Python
# 2                                      Kotlin
# 3                                         PHP
# 4                                       C/C++
#
# ...

# %%
df.tail()
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 986            Backend Developer                   10
# 987            Security Engineer                    7
# 988                      Manager                    9
# 989           Software Architect                   15
# 990          Fullstack Developer                    5
#
#     Your main technology / programming language  \
# 986                                      Python
# 987                                Not Relevant
# 988                                Not Relevant
# ...

# %%
df.describe()
# Out:
#               Age  Years of experience  \
# count  882.000000           991.000000
# mean    32.416100             8.529768
# std      5.262496             5.036320
# min     20.000000             0.000000
# 25%     29.000000             5.000000
# 50%     32.000000             8.000000
# 75%     35.000000            11.000000
# max     54.000000            30.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                       990.000000    530.000000
# mean                                      72562.212121   7857.169811
# std                                       23947.379182  10320.628344
# min                                        6000.000000      0.000000
# 25%                                       60000.000000    300.000000
# 50%                                       70000.000000   5000.000000
# 75%                                       80000.000000  10000.000000
# ...

# %%
df.drop('0',axis=1)
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 0            Fullstack Developer                   13
# 1              Backend Developer                    3
# ...

# %%
data = df.groupby(["Seniority level",'Company type'])["Yearly brutto salary (without bonus and stocks)"]

data.head(10)
# Out:
# 0      64000.0
# 1      55000.0
# 2      70000.0
# 3      63000.0
# 4      66000.0
#         ...
# 924    45600.0
# 940     6000.0
# 966    50000.0
# 977    52800.0
# 987    72000.0
# Name: Yearly brutto salary (without bonus and stocks), Length: 151, dtype: float64

# %%
df['Yearly brutto salary (without bonus and stocks)'].describe()
# Out:
# count       990.000000
# mean      72562.212121
# std       23947.379182
# min        6000.000000
# 25%       60000.000000
# 50%       70000.000000
# 75%       80000.000000
# max      216000.000000
# Name: Yearly brutto salary (without bonus and stocks), dtype: float64

# %%
df['Yearly brutto salary (without bonus and stocks)'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Your main technology / programming language'].describe()
# Out:
# count        977
# unique        42
# top       Python
# freq         205
# Name: Your main technology / programming language, dtype: object

# %%
languages={language for language in df['Your main technology / programming language']}
languages
# Out:
# {'.NET',
#  'ABAP',
#  'ASM',
#  'AWS',
#  'Azure',
#  'C/C++',
#  'Cisco',
#  'Clojure',
#  'Cobol',
#  'Elixir',
#  'Erlang',
#  'Go',
#  'Google Cloud',
#  'HR',
#  'Hadoop',
#  'Java',
#  'Javascript / Typescript',
#  'K8S',
#  'Kotlin',
#  'Kubernetes',
#  'Linux-Stack, Networking',
#  'Microsoft, Vmware',
#  'Multiple',
#  'Not Relevant',
#  'Objective-C',
#  'Openstack',
#  'PHP',
#  'Perl',
#  'PostgreSQL',
#  'Powershell',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'SAP / ABAP',
#  'SAS',
#  'SQL',
#  'Scala',
#  'Solidity',
#  'Swift',
#  'Unity',
#  'Yaml',
#  nan}
